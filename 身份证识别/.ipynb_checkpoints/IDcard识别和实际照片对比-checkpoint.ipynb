# %% [markdown]
# ## 身份证识别

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pytesseract
import cv2
import matplotlib.pyplot as plt
import dlib
import matplotlib.patches as mpatches
from skimage import io,draw,transform,color
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ### 1:将身份证转正
# 根据人脸图像将倾斜的身份证照片转正
# 利用dlib进行人脸的landmark的提取，找到左右眼的坐标，求出倾斜角度。对图像进行旋转。 再提取人脸的区域，然后根据比例，对身份证区域的估计，取出最大的估计的矩形框。
#
# 将提取的身份证上的照片和现实的照片对比，判断是否未同一个人。

# %%
## 使用dlib.get_frontal_face_detector识别人脸
detector = dlib.get_frontal_face_detector()
image = io.imread("奥巴马2.jpeg")
dets = detector(image, 2) #使用detector进行人脸检测 dets为返回的结果

# %%
## 将识别的图像可视化
plt.figure()
ax = plt.subplot(111)
ax.imshow(image)
plt.axis("off")
for i, face in enumerate(dets):
    # 在图片中标注人脸，并显示
    left = face.left()
    top = face.top()
    right = face.right()
    bottom = face.bottom()
    rect = mpatches.Rectangle((left,bottom), right - left, top - bottom,
                                  fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)
plt.show()

# %%
## 检测人脸的眼睛所在位置
predictor = dlib.shape_predictor("shape_predictor_5_face_landmarks.dat")
detected_landmarks = predictor(image, dets[0]).parts()
landmarks = np.array([[p.x, p.y] for p in detected_landmarks])

# %%
## 将眼睛位置可视化
plt.figure()
ax = plt.subplot(111)
ax.imshow(image)
plt.axis("off")
plt.plot(landmarks[0:4,0],landmarks[0:4,1],'ro')
for ii in np.arange(4):
    plt.text(landmarks[ii,0]-10,landmarks[ii,1]-15,ii)
plt.show()

# %%
## 计算眼睛的倾斜角度,逆时针角度
def twopointcor(point1,point2):
    """point1 = (x1,y1),point2 = (x2,y2)"""
    deltxy = point2 - point1
    corner = np.arctan(deltxy[1] / deltxy[0]) * 180 / np.pi
    return corner

# %%
## 计算多个角度求均值
corner10 =  twopointcor(landmarks[1,:],landmarks[0,:])
corner23 =  twopointcor(landmarks[3,:],landmarks[2,:])
corner20 =  twopointcor(landmarks[2,:],landmarks[0,:])
corner31 =  twopointcor(landmarks[3,:],landmarks[1,:])
corner = np.mean([corner10,corner23,corner20,corner31])
print(corner10)
print(corner23)
print(corner20)
print(corner31)
print(corner)
# Out:
# -9.865806943084369
# -7.765166018425334
# -10.049348588124873
# -11.633633998940436
# -9.828488887143752

# %%
## 计算图像的身份证倾斜的角度
def IDcorner(landmarks):
    """landmarks:检测的人脸5个特征点
       经过测试使用第0个和第2个特征点计算角度较合适
    """
    corner20 =  twopointcor(landmarks[2,:],landmarks[0,:])
    corner = np.mean([corner20])
    return corner
corner = IDcorner(landmarks)
print(corner)
# Out:
# -10.049348588124873

# %%
## 将照片转正 "奥巴马2.jpeg"
def rotateIdcard(image):
    "image :需要处理的图像"
    ## 使用dlib.get_frontal_face_detector识别人脸
    detector = dlib.get_frontal_face_detector()
    dets = detector(image, 2) #使用detector进行人脸检测 dets为返回的结果
    ## 检测人脸的眼睛所在位置
    predictor = dlib.shape_predictor("shape_predictor_5_face_landmarks.dat")
    detected_landmarks = predictor(image, dets[0]).parts()
    landmarks = np.array([[p.x, p.y] for p in detected_landmarks])
    corner = IDcorner(landmarks)
    ## 旋转后的图像
    image2 = transform.rotate(image,corner,clip=False)
    image2 = np.uint8(image2*255)
    ## 旋转后人脸位置
    det = detector(image2, 2)
    return image2,det

# %%
## 转正身份证：
image = io.imread("奥巴马2.jpeg")
image2,dets = rotateIdcard(image)

# %%
## 可视化修正后的结果
plt.figure()
ax = plt.subplot(111)
ax.imshow(image2)
plt.axis("off")
# 在图片中标注人脸，并显示
left = dets[0].left()
top = dets[0].top()
right = dets[0].right()
bottom = dets[0].bottom()
rect = mpatches.Rectangle((left,bottom), (right - left), (top - bottom),
                          fill=False, edgecolor='red', linewidth=1)
ax.add_patch(rect)

## 照片的位置（不怎么精确）
width = right - left
high = top - bottom
left2 = np.uint(left - 0.3*width)
bottom2 = np.uint(bottom + 0.4*width)
rect = mpatches.Rectangle((left2,bottom2), 1.6*width, 1.8*high,
                          fill=False, edgecolor='blue', linewidth=1)
ax.add_patch(rect)
plt.show()

# %%
## 身份证上人的照片
top2 = np.uint(bottom2+1.8*high)
right2 = np.uint(left2+1.6*width)
image3 = image2[top2:bottom2,left2:right2,:]
plt.imshow(image3)
plt.axis("off")
plt.show()

# %% [markdown]
# **前面我们已经找到了身份证上的人脸图像，接下来提取人脸特征和实际照片进行对比，判断是否为同一个人。**

# %%
## 读取相互对比的图像
imob1 = io.imread("Obama对比1.jpg")
imob2 = io.imread("Obama对比2.jpg")
imob3 = io.imread("Obama对比3.jpg")
imtrup = io.imread("trump对比1.jpg")
impujing = io.imread("普京对比1.jpg")

image_test = [imob1,imob2,imob3,imtrup,impujing]
plt.figure(figsize=(12,8))
for ii,im in enumerate(image_test):
    plt.subplot(2,3,ii+1)
    plt.imshow(im)
    plt.axis("off")
# Out:
# (340, 250, 3)
# (743, 1280, 3)
# (385, 550, 3)
# (415, 622, 3)
# (305, 550, 3)

# %%
im.shape
# Out:
# (331, 438, 4)

# %%
## 找到图像中的人脸
detector = dlib.get_frontal_face_detector()
plt.figure(figsize=(12,8))
for ii,im in enumerate(image_test):
    dets = detector(im, 2) #使用detector进行人脸检测 dets为返回的结果
    ## 将识别的图像可视化
    axi = plt.subplot(2,3,ii+1)
    axi.imshow(im)
    axi.axis("off")
    for i, face in enumerate(dets):
        # 在图片中标注人脸，并显示
        left = face.left()
        top = face.top()
        right = face.right()
        bottom = face.bottom()
        rect = mpatches.Rectangle((left,bottom), right - left, top - bottom,
                                      fill=False, edgecolor='red', linewidth=1)
        axi.add_patch(rect)
plt.show()

# %% [markdown]
# **可以发现人脸均已经找到**
#
# **找到身份证上照片的特征点，并和找到图像中人脸的特征点进行对比**

# %%
## 检测到人脸后，对人脸的特征点进行显示
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
image_copy = image3.copy()
dets = detector(image_copy, 2)
## 从检测到的人脸中识别特征点
detected_landmarks = predictor(image_copy, d).parts()  
landmarks = np.matrix([[p.x, p.y] for p in detected_landmarks]) 
## 将识别的图像可视化
plt.figure()
ax = plt.subplot(111)
ax.imshow(image_copy)
plt.axis("off")
for i, face in enumerate(dets):
    # 在图片中标注人脸，并显示
    left = face.left()
    top = face.top()
    right = face.right()
    bottom = face.bottom()
    rect = mpatches.Rectangle((left,bottom), right - left, top - bottom,
                                  fill=False, edgecolor='red', linewidth=1)
    ax.add_patch(rect)
    for idx, point in enumerate(landmarks): 
        pos = (point[0, 0], point[0, 1])
        ax.scatter(pos[0],pos[1],c="b",s = 10)
plt.show()

# %%
landmarks
# Out:
# matrix([[ 43,  89],
#         [ 45, 106],
#         [ 47, 124],
#         [ 51, 141],
#         [ 57, 157],
#         [ 65, 173],
#         [ 76, 186],
#         [ 90, 197],
#         [106, 200],
#         [123, 197],
#         [137, 186],
#         [149, 173],
#         [159, 157],
#         [165, 141],
#         [170, 124],
#         [172, 105],
#         [175,  87],
#         [ 55,  84],
#         [ 62,  76],
#         [ 73,  73],
#         [ 85,  74],
#         [ 96,  77],
#         [118,  77],
#         [129,  73],
#         [141,  72],
#         [153,  74],
#         [162,  81],
#         [106,  88],
#         [106, 101],
#         [106, 113],
#         [105, 125],
#         [ 92, 133],
#         [ 98, 135],
#         [105, 137],
#         [112, 135],
#         [120, 133],
#         [ 68,  91],
#         [ 74,  87],
#         [ 83,  87],
#         [ 89,  92],
#         [ 82,  93],
#         [ 74,  94],
#         [125,  91],
#         [132,  86],
#         [141,  86],
#         [148,  90],
#         [141,  93],
#         [133,  92],
#         [ 79, 156],
#         [ 89, 153],
#         [ 98, 150],
#         [105, 152],
#         [112, 150],
#         [122, 152],
#         [133, 155],
#         [123, 162],
#         [113, 166],
#         [106, 167],
#         [ 98, 166],
#         [ 89, 163],
#         [ 84, 157],
#         [ 98, 157],
#         [105, 157],
#         [112, 157],
#         [128, 156],
#         [113, 157],
#         [105, 158],
#         [ 98, 157]])

# %%
## 检测到人脸后，对人脸的特征点进行显示
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
image_copy = image3.copy()
dets = detector(image_copy, 2)
for k, d in enumerate(dets):
    # 从识别的人脸d中获得人脸特征点
    detected_landmarks = predictor(image, d).parts()  
    landmarks = np.matrix([[p.x, p.y] for p in detected_landmarks]) 
    for idx, point in enumerate(landmarks):  
        pos = (point[0, 0], point[0, 1])
        # 注释点的位置
        cv2.putText(image_copy, str(idx), pos,  
                    fontFace=cv2.FONT_HERSHEY_SIMPLEX,  
                    fontScale=0.3,  
                    color=(255, 255, 0))  

## 显示找到特征点后的图像
plt.figure(figsize=(10,8))
ax = plt.subplot(111)
ax.imshow(image_copy)
plt.axis("off")
plt.show()
