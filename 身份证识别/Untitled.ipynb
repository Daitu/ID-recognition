# %% [markdown]
# ## 身份证检测

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import matplotlib.pyplot as plt

# %%
## 识别英文文字
im = Image.open("example_03.png")
plt.figure(figsize=(8,6))
plt.imshow(im)
plt.axis("off")
plt.show()

# %%
text = pytesseract.image_to_string(im)
print(text)
# Out:
# PREREQUISITES
#
# In order :0 make the most of this, yDu will need to have
# a mug bit of pmgmnmling experience. All Examples in this
# book am in the Python programming language. Familiarity
# with Pymm. m other scripting languages is suggesied, but
# m: requimd.
#
# You'll also need to know some basic mathmadcs. This
# book is handsun and Example driven: lots of examples and
# lots of code, so even if your math skills am um up to pal,
# do um wmy! The examples axe very damned and heavily
# documented to help yuu follaw along.

# %%
## 识别中文
im = Image.open("奥巴马地址.png")
plt.imshow(im)
plt.axis("off")
plt.show()
text = pytesseract.image_to_string(im,lang='chi_sim')
print(text)
# Out:
# 任 罐 华盛慷特区董寞法尼噩
# 大遭1600号白富

# %%
## 找到字体的h
box = pytesseract.image_to_string(Image.open("孙玉林.jpg"),lang='chi_sim')
box
# Out:
# ''
